# %% [markdown]
# # Без символа подстановки

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv("fileOfTimes.csv", sep=";")

zero = data[(data["Number of substitution"] == 0) & (data["Size of text"] == 10000) & (data["Size_of_alphabet"] == 2)]

different_algorithms = zero['Type of algorithm'].unique()

for algorithm in different_algorithms:
    cur_algorithm = zero[zero['Type of algorithm'] == algorithm]

    plt.plot(cur_algorithm['Size of pattern'], cur_algorithm['Time(ns)'], label=algorithm)

plt.xlabel('Размер шаблона')
plt.ylabel('Время в наносек.')
plt.title('Без символов подстановки, 10000 символов, бинарный алфавит')

plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv("fileOfTimes.csv", sep=";")

zero = data[(data["Number of substitution"] == 0) & (data["Size of text"] == 10000) & (data["Size_of_alphabet"] == 4)]

different_algorithms = zero['Type of algorithm'].unique()

for algorithm in different_algorithms:
    cur_algorithm = zero[zero['Type of algorithm'] == algorithm]

    plt.plot(cur_algorithm['Size of pattern'], cur_algorithm['Time(ns)'], label=algorithm)

plt.xlabel('Размер шаблона')
plt.ylabel('Время в наносек.')
plt.title('Без символов подстановки, 10000 символов, 4-символьный алфавит')

plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv("fileOfTimes.csv", sep=";")

zero = data[(data["Number of substitution"] == 0) & (data["Size of text"] == 100000) & (data["Size_of_alphabet"] == 2)]

different_algorithms = zero['Type of algorithm'].unique()

for algorithm in different_algorithms:
    cur_algorithm = zero[zero['Type of algorithm'] == algorithm]

    plt.plot(cur_algorithm['Size of pattern'], cur_algorithm['Time(ns)'], label=algorithm)

plt.xlabel('Размер шаблона')
plt.ylabel('Время в наносек.')
plt.title('Без символов подстановки, 100000 символов, бинарный алфавит')

plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv("fileOfTimes.csv", sep=";")

zero = data[(data["Number of substitution"] == 0) & (data["Size of text"] == 100000) & (data["Size_of_alphabet"] == 4)]

different_algorithms = zero['Type of algorithm'].unique()

for algorithm in different_algorithms:
    cur_algorithm = zero[zero['Type of algorithm'] == algorithm]

    plt.plot(cur_algorithm['Size of pattern'], cur_algorithm['Time(ns)'], label=algorithm)

plt.xlabel('Размер шаблона')
plt.ylabel('Время в наносек.')
plt.title('Без символов подстановки, 100000 символов, 4-символьный алфавит')

plt.legend()

plt.show()

# %% [markdown]
# # 1 символ подстановки

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv("fileOfTimes.csv", sep=";")

zero = data[(data["Number of substitution"] == 1) & (data["Size of text"] == 10000) & (data["Size_of_alphabet"] == 2)]

different_algorithms = zero['Type of algorithm'].unique()

for algorithm in different_algorithms:
    cur_algorithm = zero[zero['Type of algorithm'] == algorithm]

    plt.plot(cur_algorithm['Size of pattern'], cur_algorithm['Time(ns)'], label=algorithm)

plt.xlabel('Размер шаблона')
plt.ylabel('Время в наносек.')
plt.title('1 символ подстановки, 10000 символов, бинарный алфавит')

plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv("fileOfTimes.csv", sep=";")

zero = data[(data["Number of substitution"] == 1) & (data["Size of text"] == 10000) & (data["Size_of_alphabet"] == 4)]

different_algorithms = zero['Type of algorithm'].unique()

for algorithm in different_algorithms:
    cur_algorithm = zero[zero['Type of algorithm'] == algorithm]

    plt.plot(cur_algorithm['Size of pattern'], cur_algorithm['Time(ns)'], label=algorithm)

plt.xlabel('Размер шаблона')
plt.ylabel('Время в наносек.')
plt.title('1 символ подстановки, 10000 символов, 4-символьный алфавит')

plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv("fileOfTimes.csv", sep=";")

zero = data[(data["Number of substitution"] == 1) & (data["Size of text"] == 100000) & (data["Size_of_alphabet"] == 2)]

different_algorithms = zero['Type of algorithm'].unique()

for algorithm in different_algorithms:
    cur_algorithm = zero[zero['Type of algorithm'] == algorithm]

    plt.plot(cur_algorithm['Size of pattern'], cur_algorithm['Time(ns)'], label=algorithm)

plt.xlabel('Размер шаблона')
plt.ylabel('Время в наносек.')
plt.title('1 символ подстановки, 100000 символов, бинарный алфавит')

plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv("fileOfTimes.csv", sep=";")

zero = data[(data["Number of substitution"] == 1) & (data["Size of text"] == 100000) & (data["Size_of_alphabet"] == 4)]

different_algorithms = zero['Type of algorithm'].unique()

for algorithm in different_algorithms:
    cur_algorithm = zero[zero['Type of algorithm'] == algorithm]

    plt.plot(cur_algorithm['Size of pattern'], cur_algorithm['Time(ns)'], label=algorithm)

plt.xlabel('Размер шаблона')
plt.ylabel('Время в наносек.')
plt.title('1 символ подстановки, 100000 символов, 4-символьный алфавит')

plt.legend()

plt.show()

# %% [markdown]
# # 2 символа подстановки

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv("fileOfTimes.csv", sep=";")

zero = data[(data["Number of substitution"] == 2) & (data["Size of text"] == 10000) & (data["Size_of_alphabet"] == 2)]

different_algorithms = zero['Type of algorithm'].unique()

for algorithm in different_algorithms:
    cur_algorithm = zero[zero['Type of algorithm'] == algorithm]

    plt.plot(cur_algorithm['Size of pattern'], cur_algorithm['Time(ns)'], label=algorithm)

plt.xlabel('Размер шаблона')
plt.ylabel('Время в наносек.')
plt.title('2 символа подстановки, 10000 символов, бинарный алфавит')

plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv("fileOfTimes.csv", sep=";")

zero = data[(data["Number of substitution"] == 2) & (data["Size of text"] == 10000) & (data["Size_of_alphabet"] == 4)]

different_algorithms = zero['Type of algorithm'].unique()

for algorithm in different_algorithms:
    cur_algorithm = zero[zero['Type of algorithm'] == algorithm]

    plt.plot(cur_algorithm['Size of pattern'], cur_algorithm['Time(ns)'], label=algorithm)

plt.xlabel('Размер шаблона')
plt.ylabel('Время в наносек.')
plt.title('2 символа подстановки, 10000 символов, 4-символьный алфавит')

plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv("fileOfTimes.csv", sep=";")

zero = data[(data["Number of substitution"] == 2) & (data["Size of text"] == 100000) & (data["Size_of_alphabet"] == 2)]

different_algorithms = zero['Type of algorithm'].unique()

for algorithm in different_algorithms:
    cur_algorithm = zero[zero['Type of algorithm'] == algorithm]

    plt.plot(cur_algorithm['Size of pattern'], cur_algorithm['Time(ns)'], label=algorithm)

plt.xlabel('Размер шаблона')
plt.ylabel('Время в наносек.')
plt.title('2 символа подстановки, 100000 символов, бинарный алфавит')

plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv("fileOfTimes.csv", sep=";")

zero = data[(data["Number of substitution"] == 2) & (data["Size of text"] == 100000) & (data["Size_of_alphabet"] == 4)]

different_algorithms = zero['Type of algorithm'].unique()

for algorithm in different_algorithms:
    cur_algorithm = zero[zero['Type of algorithm'] == algorithm]

    plt.plot(cur_algorithm['Size of pattern'], cur_algorithm['Time(ns)'], label=algorithm)

plt.xlabel('Размер шаблона')
plt.ylabel('Время в наносек.')
plt.title('2 символа подстановки, 100000 символов, 4-символьный алфавит')

plt.legend()

plt.show()

# %% [markdown]
# # 3 символа подстановки

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv("fileOfTimes.csv", sep=";")

zero = data[(data["Number of substitution"] == 3) & (data["Size of text"] == 10000) & (data["Size_of_alphabet"] == 2)]

different_algorithms = zero['Type of algorithm'].unique()

for algorithm in different_algorithms:
    cur_algorithm = zero[zero['Type of algorithm'] == algorithm]

    plt.plot(cur_algorithm['Size of pattern'], cur_algorithm['Time(ns)'], label=algorithm)

plt.xlabel('Размер шаблона')
plt.ylabel('Время в наносек.')
plt.title('3 символа подстановки, 10000 символов, бинарный алфавит')

plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv("fileOfTimes.csv", sep=";")

zero = data[(data["Number of substitution"] == 3) & (data["Size of text"] == 10000) & (data["Size_of_alphabet"] == 4)]

different_algorithms = zero['Type of algorithm'].unique()

for algorithm in different_algorithms:
    cur_algorithm = zero[zero['Type of algorithm'] == algorithm]

    plt.plot(cur_algorithm['Size of pattern'], cur_algorithm['Time(ns)'], label=algorithm)

plt.xlabel('Размер шаблона')
plt.ylabel('Время в наносек.')
plt.title('3 символа подстановки, 10000 символов, 4-символьный алфавит')

plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv("fileOfTimes.csv", sep=";")

zero = data[(data["Number of substitution"] == 3) & (data["Size of text"] == 100000) & (data["Size_of_alphabet"] == 2)]

different_algorithms = zero['Type of algorithm'].unique()

for algorithm in different_algorithms:
    cur_algorithm = zero[zero['Type of algorithm'] == algorithm]

    plt.plot(cur_algorithm['Size of pattern'], cur_algorithm['Time(ns)'], label=algorithm)

plt.xlabel('Размер шаблона')
plt.ylabel('Время в наносек.')
plt.title('3 символа подстановки, 100000 символов, бинарный алфавит')

plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv("fileOfTimes.csv", sep=";")

zero = data[(data["Number of substitution"] == 3) & (data["Size of text"] == 100000) & (data["Size_of_alphabet"] == 4)]

different_algorithms = zero['Type of algorithm'].unique()

for algorithm in different_algorithms:
    cur_algorithm = zero[zero['Type of algorithm'] == algorithm]

    plt.plot(cur_algorithm['Size of pattern'], cur_algorithm['Time(ns)'], label=algorithm)

plt.xlabel('Размер шаблона')
plt.ylabel('Время в наносек.')
plt.title('3 символа подстановки, 100000 символов, 4-символьный алфавит')

plt.legend()

plt.show()

# %% [markdown]
# # 4 символа подстановки

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv("fileOfTimes.csv", sep=";")

zero = data[(data["Number of substitution"] == 4) & (data["Size of text"] == 10000) & (data["Size_of_alphabet"] == 2)]

different_algorithms = zero['Type of algorithm'].unique()

for algorithm in different_algorithms:
    cur_algorithm = zero[zero['Type of algorithm'] == algorithm]

    plt.plot(cur_algorithm['Size of pattern'], cur_algorithm['Time(ns)'], label=algorithm)

plt.xlabel('Размер шаблона')
plt.ylabel('Время в наносек.')
plt.title('4 символа подстановки, 10000 символов, бинарный алфавит')

plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv("fileOfTimes.csv", sep=";")

zero = data[(data["Number of substitution"] == 4) & (data["Size of text"] == 10000) & (data["Size_of_alphabet"] == 4)]

different_algorithms = zero['Type of algorithm'].unique()

for algorithm in different_algorithms:
    cur_algorithm = zero[zero['Type of algorithm'] == algorithm]

    plt.plot(cur_algorithm['Size of pattern'], cur_algorithm['Time(ns)'], label=algorithm)

plt.xlabel('Размер шаблона')
plt.ylabel('Время в наносек.')
plt.title('4 символа подстановки, 10000 символов, 4-символьный алфавит')

plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv("fileOfTimes.csv", sep=";")

zero = data[(data["Number of substitution"] == 4) & (data["Size of text"] == 100000) & (data["Size_of_alphabet"] == 2)]

different_algorithms = zero['Type of algorithm'].unique()

for algorithm in different_algorithms:
    cur_algorithm = zero[zero['Type of algorithm'] == algorithm]

    plt.plot(cur_algorithm['Size of pattern'], cur_algorithm['Time(ns)'], label=algorithm)

plt.xlabel('Размер шаблона')
plt.ylabel('Время в наносек.')
plt.title('4 символа подстановки, 100000 символов, бинарный алфавит')

plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv("fileOfTimes.csv", sep=";")

zero = data[(data["Number of substitution"] == 4) & (data["Size of text"] == 100000) & (data["Size_of_alphabet"] == 4)]

different_algorithms = zero['Type of algorithm'].unique()

for algorithm in different_algorithms:
    cur_algorithm = zero[zero['Type of algorithm'] == algorithm]

    plt.plot(cur_algorithm['Size of pattern'], cur_algorithm['Time(ns)'], label=algorithm)

plt.xlabel('Размер шаблона')
plt.ylabel('Время в наносек.')
plt.title('4 символа подстановки, 100000 символов, 4-символьный алфавит')

plt.legend()

plt.show()
